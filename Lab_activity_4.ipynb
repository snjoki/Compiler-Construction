# %% [markdown]
# <a href="https://colab.research.google.com/github/snjoki/Compiler-Construction/blob/main/Lab_activity_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
120747
Annsonia Njoki Wanjugu
Lab Activity 4

# %% [markdown]
# 1. A predictive parser is a recursive descent parser with no backtracking or backup. It is a top-down parser that does not require backtracking. At each step, the choice of the rule to be expanded is made upon the next terminal symbol.

# %% [markdown]
# ![predictive parser.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 2. a. LL(1) Parsing
# A top-down parser that uses a one-token lookahead is called an LL(1) parser.
#
# The first L indicates that the input is read from left to right.
#
# The second L says that it produces a left-to-right derivation.
#
# And the 1 says that it uses one lookahead token. (Some parsers look ahead at the next 2 tokens, or even more than that.)

# %% [markdown]
# b.  We need to find FIRST and FOLLOW sets for a given grammar so that the parser can properly apply the needed rule at the correct position. First of a Non-Terminal gives list of elements which can be replaced "FIRST ", when you expand the corresponding Non Terminal. Whereas the Follow set gives list of those elements which can FOLLOW to right of that Nonterminal when you are expanding a string containing that NonTerminal.

# %% [markdown]
# 3. Unique attributes associated with top-down parsing
#
#   1. Recursive descent is a top-down parsing technique that constructs the parse tree from the top and the input is read from left to right. It uses procedures for every terminal and non-terminal entity. This parsing technique recursively parses the input to make a parse tree, which may or may not require back-tracking. But the grammar associated with it (if not left factored) cannot avoid back-tracking. A form of recursive-descent parsing that does not require any back-tracking is known as predictive parsing.
#
#   2. The top-down parser allows for the incremental calculation of generative
# conditional word probabilities, a property it shares with other left-to-right parsers with rooted derivations.

# %% [markdown]
# References
# 1. https://slideplayer.com/slide/8745493/
# 2. https://www.geeksforgeeks.org/predictive-parser-in-compiler-design/
